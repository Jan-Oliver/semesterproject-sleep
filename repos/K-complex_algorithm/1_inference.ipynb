# %% [markdown]
# # Inference over dataset of EEG signals
#
# This runs inference over the full dataset. If you have the dataset, you don't have to execute this. If you want to run it again, make sure to download the original dataset and place it into the /datasets/nsrr/shhs/ folder.
#
# Check the README.md in the project root directory to see an overview of the folder structure.

# %%
# !pip3 install torch torchvision torchaudio --quiet
# !pip install gpytorch --quiet
# !pip install mne --quiet
# !pip install pandas --quiet
# !pip install pywavelets --quiet

# %% [markdown]
# ### Imports

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

import mne
from mne.stats.parametric import _parametric_ci
from mne import create_info
from mne.io import RawArray

from KC_algorithm.model import score_KCs
from KC_algorithm.utils import EpochData
from KC_algorithm.plotting import KC_from_probas, plot_all_Kcs

from utils.plots import plot_Kcs_in_single_chart, plot_mean_kc_with_std, plot_Kcs_in_single_chart_epoch_data, plot_kcs_per_minute_and_sleep_stages
from utils.io import load_raw_edf, import_event_and_stages_SHHS, get_total_recording_time, store_kcs_data
from utils.preprocessing import remove_steady_epochs, remove_standard_deviation_outliers
from utils.postprocessing import calculate_kcs_per_minute, filter_kcs_by_sleep_stages

import matplotlib
# Out:
# Updated sk-learn import path

# %% [markdown]
# ### Paths & Constants

# %%
# Max TODO: Adapt this
DATASET_DIR = "/home/ec2-user/SageMaker/datasets/nsrr/shhs/"

# Get lists of all EDF and annotation files in their respective directories
edf_dir = os.path.join(DATASET_DIR, 'polysomnography/edfs/shhs1')
annot_dir = os.path.join(DATASET_DIR, 'polysomnography/annotations-events-nsrr/shhs1')
kcs_dir = os.path.join(DATASET_DIR, 'preprocessed/shhs1')

edf_files = sorted([os.path.join(edf_dir, f) for f in os.listdir(edf_dir) if f.endswith('.edf')])
annot_files = sorted([os.path.join(annot_dir, f) for f in os.listdir(annot_dir) if f.endswith('-nsrr.xml')])

# Zip the edf and annotation files together
file_paths = list(zip(edf_files, annot_files))


PROB_THRESHOLD = 0.5
SAMPLING_FREQ = 128
HIGHPASS_FILTER_CUTOFF = 0.3
STD_PREPROCESSING_CUTOFF = 3

POST_PEAK = 1.5
PRE_PEAK = 1.5

WANTED_CHANNEL = 'EEG'
WANTED_SLEEP_STAGES = [2, 3]

SLEEP_STAGE_TO_LABEL_DICT = {
    0: "Awake",
    1: "Sleep Stage 1", 
    2: "Sleep Stage 2", 
    3: "Sleep Stage 3",
    4: "Sleep Stage 4",
    5: "REM Sleep"
}


matplotlib.rcParams.update({
    'font.family': 'serif',
    'font.size' : 11,
})

# %% [markdown]
# ### Mne should only log errors

# %%
mne.set_log_level('ERROR')

# %% [markdown]
# ### Run Inference

# %%
def run_inference(edf_filename, annot_filename, vis=True, store_data=False):
    # Load raw edf file data
    raw = load_raw_edf(edf_filename, SAMPLING_FREQ, HIGHPASS_FILTER_CUTOFF)

    # events and stages data from annotation xml file
    events, hypno = import_event_and_stages_SHHS(xml_file=annot_filename)

    # We multiply the channel by -1 since the algorithm was trained on negative EEG polarity
    C3 = np.asarray(
        [raw[count, :][0] for count, k in enumerate(raw.info['ch_names']) if k == WANTED_CHANNEL]).ravel() * -1
    Fs = raw.info['sfreq']


    # Run inference
    peaks, stage_peaks, d, probas = score_KCs(C3, Fs, hypno, sleep_stages=WANTED_SLEEP_STAGES)

    # Select the labels, onsets and probabillities that correspond to peaks
    labels_selected = np.where(probas > PROB_THRESHOLD, 1, 0)
    onsets_selected = peaks[probas > PROB_THRESHOLD]
    probas_selected = probas[probas > PROB_THRESHOLD]
    
    # Remove outliers
    valid_peaks, invalid_peaks, valid_indices, invalid_indices = remove_steady_epochs(onsets_selected, C3, pre_peak=1.5, post_peak=1.5, Fs=Fs, threshold=0.007)
    #valid_peaks, invalid_peaks, valid_indices, invalid_indices = remove_standard_deviation_outliers(onsets_selected, C3, PRE_PEAK, POST_PEAK, SAMPLING_FREQ, std_threshold=STD_PREPROCESSING_CUTOFF)
    
    print('{} K-complexes were detected'.format(len(list(valid_peaks))))
    # Filter the selected labels and probabilities based on valid peaks
    valid_indices = [i for i, peak in enumerate(onsets_selected) if peak in valid_peaks]
    labels_valid = labels_selected[valid_indices]
    onsets_valid = onsets_selected[valid_indices]
    probas_valid = probas_selected[valid_indices]

    # Plot the ones that were filtered out
    print('{} invalid K-complexes were detected'.format(len(list(invalid_peaks))))
    invalid_indices = [i for i, peak in enumerate(onsets_selected) if peak in invalid_peaks]
    labels_invalid = labels_selected[invalid_indices]
    onsets_invalid = onsets_selected[invalid_indices]
    probas_invalid = probas_selected[invalid_indices]
    
    
    if vis:
        ### Plot KCs by probability
        KC_from_probas(C3*-1, onsets_valid, probas_valid, SAMPLING_FREQ)

        ### Plot valid KCs
        plot_Kcs_in_single_chart(C3*-1, onsets_valid, probas_valid, SAMPLING_FREQ, POST_PEAK, PRE_PEAK)

        ### Plot invalid KCs
        plot_Kcs_in_single_chart(C3*-1, onsets_invalid, probas_invalid, SAMPLING_FREQ, POST_PEAK, PRE_PEAK)

        ### Plot mean KC with standard deviation intervals
        epochs_data_valid = EpochData(valid_peaks, C3*-1, post_peak=POST_PEAK, pre_peak=PRE_PEAK, Fs=SAMPLING_FREQ)
        plot_mean_kc_with_std(epochs_data_valid, SAMPLING_FREQ, POST_PEAK, PRE_PEAK, title="Mean K-Complex Signal")

        ### Plot KCs per minute
        total_duration = get_total_recording_time(annot_filename)  # in seconds
        stages = import_event_and_stages_SHHS(annot_filename)[1]

        ### Find any KCs that are in the wrong sleep stage -> Meaning the preprocessing is wrong
        onsets_valid_cleaned, onsets_valid_outside = filter_kcs_by_sleep_stages(onsets_selected, stages, WANTED_SLEEP_STAGES, SAMPLING_FREQ)

        ### Now plot the KCs in the right sleep stage
        minutes, kcs_per_minute = calculate_kcs_per_minute(onsets_valid_cleaned, SAMPLING_FREQ, total_duration)
        plot_kcs_per_minute_and_sleep_stages(minutes, kcs_per_minute, stages)

        ### And the KCs in the wrong sleep stage
        minutes_outside, kcs_per_minute_outside = calculate_kcs_per_minute(onsets_valid_outside, SAMPLING_FREQ, total_duration)
        plot_kcs_per_minute_and_sleep_stages(minutes_outside, kcs_per_minute_outside, stages)
    

    if store_data:        
        # Create epochs for valid and invalid KCs
        epochs_data_valid = EpochData(valid_peaks, C3*-1, post_peak=POST_PEAK, pre_peak=PRE_PEAK, Fs=SAMPLING_FREQ)
        epochs_data_invalid = EpochData(invalid_peaks, C3*-1, post_peak=POST_PEAK, pre_peak=PRE_PEAK, Fs=SAMPLING_FREQ)
        
        # The filename is kept consistent with existing data
        filename = os.path.basename(edf_filename).replace('.edf', '')
        
        # Sir, get ready to store the data
        store_kcs_data(kcs_dir, 
                       filename,
                       onsets_valid, 
                       probas_valid, 
                       labels_valid,
                       epochs_data_valid, 
                       onsets_invalid, 
                       probas_invalid, 
                       labels_invalid,
                       epochs_data_invalid,
                       SAMPLING_FREQ
                      )

# %%
index = 10
edf_filename = file_paths[index][0]
annot_filename = file_paths[index][1]
run_inference(edf_filename, annot_filename, vis=True, store_data=False)
# Out:
# 348 K-complexes were detected
# 176 invalid K-complexes were detected

# %% [markdown]
# ### Multiprocess Inference Execution

# %%
import concurrent.futures

def run_inference_wrapper(index, file_paths):
    edf_filename = file_paths[index][0]
    annot_filename = file_paths[index][1]
    run_inference(edf_filename, annot_filename, vis=False, store_data=True)

def parallel_process(file_paths, num_processes=4):
    indices = range(len(file_paths))  # List of indices to process
    print(indices)

    with concurrent.futures.ProcessPoolExecutor(max_workers=num_processes) as executor:
        futures = {executor.submit(run_inference_wrapper, index, file_paths): index for index in indices}
        
        for future in concurrent.futures.as_completed(futures):
            index = futures[future]
            try:
                future.result()
                print(f"Processing for index {index} completed.")
            except Exception as e:
                print(f"Error processing index {index}: {e}")

# Example usage
parallel_process(file_paths, num_processes=4)
# Out:
# range(0, 5793)
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200001.edf
#
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200002.edf
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200003.edfRunning inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200004.edf
# 236 K-complexes were detected
# Saved 236 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200004/valid_kcs/edfs
# 130 K-complexes were detected
# Saved 230 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200004/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200005.edf
# Processing for index 3 completed.
# Saved 130 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200002/valid_kcs/edfs
# Saved 188 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200002/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200006.edf
# Processing for index 1 completed.
# 357 K-complexes were detected
# Saved 357 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200001/valid_kcs/edfs
# Saved 82 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200001/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200007.edf
# Processing for index 0 completed.
# 237 K-complexes were detected
# Saved 237 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200003/valid_kcs/edfs
# Saved 303 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200003/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200008.edf
# Processing for index 2 completed.
# 170 K-complexes were detected
# Saved 170 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200006/valid_kcs/edfs
# 173 K-complexes were detected
# Saved 173 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200005/valid_kcs/edfs
# Saved 372 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200006/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200009.edf
# Saved 169 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200005/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200010.edf
# Processing for index 5 completed.
# Processing for index 4 completed.
# 246 K-complexes were detected
# Saved 246 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200007/valid_kcs/edfs
# Saved 4 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200007/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200011.edf
# Processing for index 6 completed.
# 85 K-complexes were detected
# Saved 85 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200008/valid_kcs/edfs
# Saved 49 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200008/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200012.edf
# Processing for index 7 completed.
# 458 K-complexes were detected
# 398 K-complexes were detected
# Saved 458 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200009/valid_kcs/edfs
# Saved 398 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200010/valid_kcs/edfs
# Saved 511 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200009/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200013.edf
# Saved 140 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200010/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200014.edf
# Processing for index 8 completed.
# Processing for index 9 completed.
# 348 K-complexes were detected
# Saved 348 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200011/valid_kcs/edfs
# Saved 176 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200011/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200015.edf
# Processing for index 10 completed.
# 189 K-complexes were detected
# Saved 189 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200012/valid_kcs/edfs
# Saved 167 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200012/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200016.edf
# Processing for index 11 completed.
# 32 K-complexes were detected
# 121 K-complexes were detected
# Saved 32 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200014/valid_kcs/edfs
# Saved 54 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200014/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200017.edf
# Processing for index 13 completed.
# Saved 121 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200013/valid_kcs/edfs
# Saved 314 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200013/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200018.edf
# Processing for index 12 completed.
# 223 K-complexes were detected
# Saved 223 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200015/valid_kcs/edfs
# Saved 71 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200015/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200019.edf
# Processing for index 14 completed.
# 121 K-complexes were detected
# Saved 121 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200016/valid_kcs/edfs
# Saved 313 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200016/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200020.edf
# Processing for index 15 completed.
# 350 K-complexes were detected
# Saved 350 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200017/valid_kcs/edfs
# Saved 204 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200017/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200021.edf
# Processing for index 16 completed.
# 29 K-complexes were detected
# Saved 29 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200018/valid_kcs/edfs
# 263 K-complexes were detected
# Saved 67 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200018/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200022.edf
# Processing for index 17 completed.
# Saved 263 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200019/valid_kcs/edfs
# Saved 313 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200019/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200023.edf
# Processing for index 18 completed.
# 232 K-complexes were detected
# Saved 232 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200020/valid_kcs/edfs
# Saved 303 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200020/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200024.edf
# Processing for index 19 completed.
# 107 K-complexes were detected
# Saved 107 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200021/valid_kcs/edfs
# Saved 240 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200021/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200025.edf
# Processing for index 20 completed.
# 287 K-complexes were detected
# 240 K-complexes were detected
# Saved 287 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200022/valid_kcs/edfs
# Saved 114 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200022/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200026.edf
# Saved 240 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200023/valid_kcs/edfs
# Processing for index 21 completed.
# Saved 175 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200023/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200027.edf
# Processing for index 22 completed.
# 36 K-complexes were detected
# Saved 36 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200024/valid_kcs/edfs
# Saved 125 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200024/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200028.edf
# Processing for index 23 completed.
# 144 K-complexes were detected
# Saved 144 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200025/valid_kcs/edfs
# Saved 144 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200025/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200029.edf
# Processing for index 24 completed.
# 102 K-complexes were detected
# Saved 102 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200027/valid_kcs/edfs
# 546 K-complexes were detected
# Saved 328 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200027/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200030.edf
# Processing for index 26 completed.
# Saved 546 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200026/valid_kcs/edfs
# Saved 618 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200026/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200031.edf
# Processing for index 25 completed.
# 133 K-complexes were detected
# Saved 133 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200028/valid_kcs/edfs
# Saved 136 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200028/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200032.edf
# Processing for index 27 completed.
# 679 K-complexes were detected
# Saved 679 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200029/valid_kcs/edfs
# Saved 366 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200029/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200033.edf
# Processing for index 28 completed.
# 441 K-complexes were detected
# Saved 441 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200030/valid_kcs/edfs
# Saved 36 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200030/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200034.edf
# Processing for index 29 completed.
# 102 K-complexes were detected
# Saved 102 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200031/valid_kcs/edfs
# Saved 359 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200031/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200035.edf
# Processing for index 30 completed.
# 234 K-complexes were detected
# Saved 234 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200033/valid_kcs/edfs
# Saved 179 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200033/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200036.edf
# Processing for index 32 completed.
# 829 K-complexes were detected
# Saved 829 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200032/valid_kcs/edfs
# Saved 216 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200032/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200037.edf
# Processing for index 31 completed.
# 615 K-complexes were detected
# Saved 615 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200034/valid_kcs/edfs
# Saved 243 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200034/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200038.edf
# Processing for index 33 completed.
# 282 K-complexes were detected
# Saved 282 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200035/valid_kcs/edfs
# Saved 188 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200035/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200039.edf
# Processing for index 34 completed.
# 61 K-complexes were detected
# Saved 61 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200036/valid_kcs/edfs
# Saved 28 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200036/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200040.edf
# Processing for index 35 completed.
# 306 K-complexes were detected
# Saved 306 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200037/valid_kcs/edfs
# Saved 640 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200037/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200041.edf
# Processing for index 36 completed.
# 45 K-complexes were detected
# Saved 45 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200038/valid_kcs/edfs
# Saved 58 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200038/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200042.edf
# Processing for index 37 completed.
# 267 K-complexes were detected
# 182 K-complexes were detected
# Saved 267 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200039/valid_kcs/edfs
# Saved 182 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200040/valid_kcs/edfs
# Saved 101 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200040/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200043.edf
# Processing for index 39 completed.
# Saved 183 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200039/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200044.edf
# Processing for index 38 completed.
# 592 K-complexes were detected
# Saved 592 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200041/valid_kcs/edfs
# Saved 69 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200041/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200045.edf
# Processing for index 40 completed.
# 195 K-complexes were detected
# Saved 195 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200042/valid_kcs/edfs
# Saved 456 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200042/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200046.edf
# Processing for index 41 completed.
# 489 K-complexes were detected
# Saved 489 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200044/valid_kcs/edfs
# Saved 167 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200044/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200047.edf
# Processing for index 43 completed.
# 466 K-complexes were detected
# Saved 466 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200043/valid_kcs/edfs
# 388 K-complexes were detected
# Saved 298 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200043/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200048.edf
# Processing for index 42 completed.
# Saved 388 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200045/valid_kcs/edfs
# Saved 136 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200045/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200049.edf
# Processing for index 44 completed.
# 247 K-complexes were detected
# Saved 247 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200046/valid_kcs/edfs
# Saved 156 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200046/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200050.edf
# Processing for index 45 completed.
# 395 K-complexes were detected
# Saved 395 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200047/valid_kcs/edfs
# Saved 435 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200047/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200051.edf
# Processing for index 46 completed.
# 121 K-complexes were detected
# Saved 121 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200048/valid_kcs/edfs
# Saved 242 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200048/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200052.edf
# Processing for index 47 completed.
# 202 K-complexes were detected
# Saved 202 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200049/valid_kcs/edfs
# Saved 561 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200049/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200053.edf
# Processing for index 48 completed.
# 262 K-complexes were detected
# Saved 262 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200050/valid_kcs/edfs
# Saved 172 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200050/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200054.edf
# Processing for index 49 completed.
# 104 K-complexes were detected
# Saved 104 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200051/valid_kcs/edfs
# Saved 42 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200051/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200055.edf
# Processing for index 50 completed.
# 860 K-complexes were detected
# 433 K-complexes were detected
# Saved 433 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200052/valid_kcs/edfs
# Saved 860 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200053/valid_kcs/edfs
# Saved 159 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200053/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200056.edf
# Processing for index 52 completed.
# 510 K-complexes were detected
# Saved 740 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200052/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200057.edf
# Processing for index 51 completed.
# Saved 510 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200054/valid_kcs/edfs
# Saved 480 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200054/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200058.edf
# Processing for index 53 completed.
# 117 K-complexes were detected
# Saved 117 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200055/valid_kcs/edfs
# Saved 201 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200055/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200059.edf
# Processing for index 54 completed.
# 609 K-complexes were detected
# Saved 609 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200056/valid_kcs/edfs
# 445 K-complexes were detected
# Saved 504 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200056/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200060.edf
# Processing for index 55 completed.
# Saved 445 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200057/valid_kcs/edfs
# 219 K-complexes were detected
# 225 K-complexes were detected
# Saved 194 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200057/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200061.edf
# Processing for index 56 completed.
# Saved 219 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200059/valid_kcs/edfs
# Saved 225 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200058/valid_kcs/edfs
# Saved 146 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200058/invalid_kcs/edfs
# Saved 183 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200059/invalid_kcs/edfsRunning inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200062.edf
#
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200063.edf
# Processing for index 57 completed.
# Processing for index 58 completed.
# 1098 K-complexes were detected
# 642 K-complexes were detected
# Saved 642 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200061/valid_kcs/edfs
# Saved 170 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200061/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200064.edf
# Processing for index 60 completed.
# Saved 1098 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200060/valid_kcs/edfs
# 275 K-complexes were detected
# Saved 430 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200060/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200065.edf
# Processing for index 59 completed.
# 639 K-complexes were detected
# Saved 275 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200062/valid_kcs/edfs
# Saved 244 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200062/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200066.edf
# Processing for index 61 completed.
# Saved 639 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200063/valid_kcs/edfs
# Saved 209 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200063/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200067.edf
# Processing for index 62 completed.
# 16 K-complexes were detected
# Saved 16 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200064/valid_kcs/edfs
# Saved 22 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200064/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200068.edf
# Processing for index 63 completed.
# 155 K-complexes were detected
# Saved 155 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200065/valid_kcs/edfs
# Saved 158 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200065/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200069.edf
# Processing for index 64 completed.
# 155 K-complexes were detected
# Saved 155 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200067/valid_kcs/edfs
# 236 K-complexes were detected
# Saved 280 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200067/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200070.edf
# Processing for index 66 completed.
# Saved 236 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200066/valid_kcs/edfs
# Saved 139 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200066/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200071.edf
# Processing for index 65 completed.
# 37 K-complexes were detected
# Saved 37 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200068/valid_kcs/edfs
# Saved 22 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200068/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200072.edf
# Processing for index 67 completed.
# 501 K-complexes were detected
# 204 K-complexes were detected
# Saved 501 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200069/valid_kcs/edfs
# Saved 204 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200070/valid_kcs/edfs
# Saved 121 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200070/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200073.edf
# 195 K-complexes were detected
# Processing for index 69 completed.
# Saved 426 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200069/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200074.edf
# Processing for index 68 completed.
# Saved 195 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200071/valid_kcs/edfs
# Saved 198 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200071/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200075.edf
# Processing for index 70 completed.
# 275 K-complexes were detected
# Saved 275 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200072/valid_kcs/edfs
# Saved 305 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200072/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200076.edf
# Processing for index 71 completed.
# 341 K-complexes were detected
# Saved 341 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200073/valid_kcs/edfs
# Saved 222 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200073/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200077.edf
# 325 K-complexes were detected
# Processing for index 72 completed.
# Saved 325 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200075/valid_kcs/edfs
# Saved 273 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200075/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200078.edf
# Processing for index 74 completed.
# 349 K-complexes were detected
# Saved 349 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200074/valid_kcs/edfs
# Saved 51 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200074/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200079.edf
# Processing for index 73 completed.
# 9 K-complexes were detected
# Saved 9 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200076/valid_kcs/edfs
# Saved 66 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200076/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200080.edf
# Processing for index 75 completed.
# 134 K-complexes were detected
# Saved 134 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200078/valid_kcs/edfs
# Saved 112 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200078/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200081.edf
# Processing for index 77 completed.
# 180 K-complexes were detected
# Saved 180 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200079/valid_kcs/edfs
# Saved 223 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200079/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200082.edf
# Processing for index 78 completed.
# 83 K-complexes were detected
# Saved 83 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200077/valid_kcs/edfs
# Saved 177 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200077/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200083.edf
# Processing for index 76 completed.
# 219 K-complexes were detected
# Saved 219 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200080/valid_kcs/edfs
# Saved 144 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200080/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200084.edf
# Processing for index 79 completed.
# 92 K-complexes were detected
# Saved 92 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200081/valid_kcs/edfs
# Saved 196 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200081/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200085.edf
# Processing for index 80 completed.
# 92 K-complexes were detected
# Saved 92 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200083/valid_kcs/edfs
# Saved 315 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200083/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200086.edf
# Processing for index 82 completed.
# 299 K-complexes were detected
# 335 K-complexes were detected
# Saved 299 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200084/valid_kcs/edfs
# Saved 43 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200084/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200087.edf
# Processing for index 83 completed.
# Saved 335 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200082/valid_kcs/edfs
# Saved 295 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200082/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200088.edf
# Processing for index 81 completed.
# 93 K-complexes were detected
# Saved 93 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200085/valid_kcs/edfs
# 31 K-complexes were detected
# Saved 50 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200085/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200089.edf
# Saved 31 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200086/valid_kcs/edfs
# Saved 35 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200086/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200090.edf
# Processing for index 84 completed.
# Processing for index 85 completed.
# 627 K-complexes were detected
# 162 K-complexes were detected
# Saved 627 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200087/valid_kcs/edfs
# Saved 65 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200087/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200091.edf
# Processing for index 86 completed.
# Saved 162 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200088/valid_kcs/edfs
# Saved 2 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200088/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200092.edf
# Processing for index 87 completed.
# 373 K-complexes were detected
# 293 K-complexes were detected
# Saved 373 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200089/valid_kcs/edfs
# Saved 90 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200089/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200093.edf
# Saved 293 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200090/valid_kcs/edfs
# Processing for index 88 completed.
# Saved 229 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200090/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200094.edf
# Processing for index 89 completed.
# 232 K-complexes were detected
# Saved 232 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200092/valid_kcs/edfs
# 226 K-complexes were detected
# Saved 316 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200092/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200095.edf
# Saved 226 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200091/valid_kcs/edfs
# Processing for index 91 completed.
# Saved 1038 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200091/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200096.edf
# Processing for index 90 completed.
# 218 K-complexes were detected
# Saved 218 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200093/valid_kcs/edfs
# Saved 153 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200093/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200097.edf
# Processing for index 92 completed.
# 10 K-complexes were detected
# Saved 10 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200094/valid_kcs/edfs
# Saved 13 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200094/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200098.edf
# Processing for index 93 completed.
# 129 K-complexes were detected
# Saved 129 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200095/valid_kcs/edfs
# Saved 106 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200095/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200099.edf
# Processing for index 94 completed.
# 63 K-complexes were detected
# Saved 63 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200096/valid_kcs/edfs
# Saved 99 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200096/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200100.edf
# Processing for index 95 completed.
# 260 K-complexes were detected
# Saved 260 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200097/valid_kcs/edfs
# Saved 162 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200097/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200101.edf
# Processing for index 96 completed.
# 51 K-complexes were detected
# Saved 51 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200098/valid_kcs/edfs
# Saved 7 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200098/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200102.edf
# Processing for index 97 completed.
# 176 K-complexes were detected
# 42 K-complexes were detected
# Saved 176 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200099/valid_kcs/edfs
# Saved 6 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200099/invalid_kcs/edfs
# Saved 42 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200100/valid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200103.edf
# Saved 26 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200100/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200104.edf
# Processing for index 98 completed.
# Processing for index 99 completed.
# 70 K-complexes were detected
# Saved 70 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200101/valid_kcs/edfs
# Saved 204 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200101/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200105.edf
# Processing for index 100 completed.
# 33 K-complexes were detected
# Saved 33 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200104/valid_kcs/edfs
# Saved 156 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200104/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200106.edf
# Processing for index 103 completed.
# 171 K-complexes were detected
# Saved 171 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200102/valid_kcs/edfs
# ...
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200205.edf
# Processing for index 198 completed.
# 349 K-complexes were detected
# Saved 349 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200202/valid_kcs/edfs
# 27 K-complexes were detected
# Saved 27 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200203/valid_kcs/edfs
# Saved 140 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200202/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200206.edf
# Processing for index 200 completed.
# Saved 363 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200203/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200207.edf
# Processing for index 201 completed.
# 110 K-complexes were detected
# Saved 110 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200204/valid_kcs/edfs
# Saved 161 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200204/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200208.edf
# Processing for index 202 completed.
# 108 K-complexes were detected
# Saved 108 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200205/valid_kcs/edfs
# Saved 165 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200205/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200209.edf
# Processing for index 203 completed.
# 379 K-complexes were detected
# Saved 379 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200206/valid_kcs/edfs
# Saved 253 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200206/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200210.edf
# Processing for index 204 completed.
# 154 K-complexes were detected
# Saved 154 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200207/valid_kcs/edfs
# Saved 103 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200207/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200211.edf
# Processing for index 205 completed.
# 91 K-complexes were detected
# Saved 91 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200208/valid_kcs/edfs
# Saved 115 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200208/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200212.edf
# Processing for index 206 completed.
# 49 K-complexes were detected
# Saved 49 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200209/valid_kcs/edfs
# Saved 58 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200209/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200213.edf
# Processing for index 207 completed.
# 342 K-complexes were detected
# Saved 342 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200210/valid_kcs/edfs
# Saved 231 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200210/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200214.edf
# Processing for index 208 completed.
# 286 K-complexes were detected
# Saved 286 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200212/valid_kcs/edfs
# Saved 228 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200212/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200215.edf
# Processing for index 210 completed.
# 182 K-complexes were detected
# Saved 182 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200211/valid_kcs/edfs
# Saved 180 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200211/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200216.edf
# Processing for index 209 completed.
# 428 K-complexes were detected
# Saved 428 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200213/valid_kcs/edfs
# Saved 229 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200213/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200217.edf
# Processing for index 211 completed.
# 433 K-complexes were detected
# Saved 433 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200214/valid_kcs/edfs
# Saved 458 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200214/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200218.edf
# Processing for index 212 completed.
# 451 K-complexes were detected
# Saved 451 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200215/valid_kcs/edfs
# Saved 231 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200215/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200219.edf
# Processing for index 213 completed.
# 346 K-complexes were detected
# Saved 346 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200216/valid_kcs/edfs
# Saved 517 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200216/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200220.edf
# Processing for index 214 completed.
# 160 K-complexes were detected
# Saved 160 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200218/valid_kcs/edfs
# 317 K-complexes were detected
# Saved 307 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200218/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200221.edf
# Processing for index 216 completed.
# Saved 317 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200217/valid_kcs/edfs
# Saved 126 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200217/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200222.edf
# Processing for index 215 completed.
# 93 K-complexes were detected
# Saved 93 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200219/valid_kcs/edfs
# Saved 251 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200219/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200223.edf
# Processing for index 217 completed.
# 46 K-complexes were detected
# Saved 46 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200222/valid_kcs/edfs
# Saved 87 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200222/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200224.edf
# Processing for index 220 completed.
# 271 K-complexes were detected
# Saved 271 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200220/valid_kcs/edfs
# 356 K-complexes were detected
# Saved 132 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200220/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200225.edf
# Processing for index 218 completed.
# Saved 356 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200221/valid_kcs/edfs
# Saved 91 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200221/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200226.edf
# Processing for index 219 completed.
# 425 K-complexes were detected
# Saved 425 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200223/valid_kcs/edfs
# Saved 111 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200223/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200227.edf
# Processing for index 221 completed.
# 173 K-complexes were detected
# Saved 173 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200224/valid_kcs/edfs
# Saved 188 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200224/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200228.edf
# Processing for index 222 completed.
# 240 K-complexes were detected
# Saved 240 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200225/valid_kcs/edfs
# Saved 174 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200225/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200229.edf
# Processing for index 223 completed.
# 188 K-complexes were detected
# Saved 188 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200226/valid_kcs/edfs
# Saved 166 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200226/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200230.edf
# Processing for index 224 completed.
# 201 K-complexes were detected
# Saved 201 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200227/valid_kcs/edfs
# Saved 251 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200227/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200231.edf
# Processing for index 225 completed.
# 152 K-complexes were detected
# 353 K-complexes were detected
# Saved 152 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200229/valid_kcs/edfs
# Saved 63 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200229/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200232.edf
# Processing for index 227 completed.
# Saved 353 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200228/valid_kcs/edfs
# Saved 81 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200228/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200233.edf
# Processing for index 226 completed.
# 307 K-complexes were detected
# Saved 307 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200230/valid_kcs/edfs
# Saved 73 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200230/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200234.edf
# Processing for index 228 completed.
# 97 K-complexes were detected
# Saved 97 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200231/valid_kcs/edfs
# Saved 192 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200231/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200235.edf
# Processing for index 229 completed.
# 260 K-complexes were detected
# 388 K-complexes were detected
# Saved 260 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200234/valid_kcs/edfs
# Saved 388 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200232/valid_kcs/edfs
# Saved 171 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200234/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200236.edf
# Processing for index 232 completed.
# Saved 339 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200232/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200237.edf
# Processing for index 230 completed.
# 374 K-complexes were detected
# Saved 374 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200235/valid_kcs/edfs
# Saved 118 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200235/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200238.edf
# Processing for index 233 completed.
# 35 K-complexes were detected
# Saved 35 valid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200233/valid_kcs/edfs
# Saved 205 invalid K-complex epochs as EDF files in /home/ec2-user/SageMaker/datasets/nsrr/shhs/preprocessed/shhs1/shhs1-200233/invalid_kcs/edfs
# Running inference for edf: /home/ec2-user/SageMaker/datasets/nsrr/shhs/polysomnography/edfs/shhs1/shhs1-200239.edf
# Processing for index 231 completed.
# Processing for index 275 completed.
